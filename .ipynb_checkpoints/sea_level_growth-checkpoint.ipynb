# %%
import pandas as pd

# %%
# display all available columns (can do with rows)
pd.set_option("display.max_columns", 28)

# %%
sea_levels = pd.read_csv('sea_level_projections.csv')

# %%
filter_pt3_low = (sea_levels['Scenario'] == '0.3 - LOW')
filter_pt3_med = (sea_levels['Scenario'] == '0.3 - MED')
filter_pt3_high = (sea_levels['Scenario'] == '0.3 - HIGH')

filter_pt5_low = (sea_levels['Scenario'] == '0.5 - LOW')
filter_pt5_med = (sea_levels['Scenario'] == '0.5 - MED')
filter_pt5_high = (sea_levels['Scenario'] == '0.5 - HIGH')

filter_1pt_low = (sea_levels['Scenario'] == '1.0 - LOW')
filter_1pt_med = (sea_levels['Scenario'] == '1.0 - MED')
filter_1pt_high = (sea_levels['Scenario'] == '1.0 - HIGH')

filter_1pt5_low = (sea_levels['Scenario'] == '1.5 - LOW')
filter_1pt5_med = (sea_levels['Scenario'] == '1.5 - MED')
filter_1pt5_high = (sea_levels['Scenario'] == '1.5 - HIGH')

filter_2pt_low = (sea_levels['Scenario'] == '2.0 - LOW')
filter_2pt_med = (sea_levels['Scenario'] == '2.0 - MED')
filter_2pt_high = (sea_levels['Scenario'] == '2.0 - HIGH')

# %%
sea_levels_pt3_low = sea_levels.loc[filter_pt3_low]
sea_levels_pt3_med = sea_levels.loc[filter_pt3_med]
sea_levels_pt3_high = sea_levels.loc[filter_pt3_high]

sea_levels_pt5_low = sea_levels.loc[filter_pt5_low]
sea_levels_pt5_med = sea_levels.loc[filter_pt5_med]
sea_levels_pt5_high = sea_levels.loc[filter_pt5_high]

sea_levels_1pt_low = sea_levels.loc[filter_1pt_low]
sea_levels_1pt_med = sea_levels.loc[filter_1pt_med]
sea_levels_1pt_high = sea_levels.loc[filter_1pt_high]

sea_levels_1pt5_low = sea_levels.loc[filter_1pt5_low]
sea_levels_1pt5_med = sea_levels.loc[filter_1pt5_med]
sea_levels_1pt5_high = sea_levels.loc[filter_1pt5_high]

sea_levels_2pt_low = sea_levels.loc[filter_2pt_low]
sea_levels_2pt_med = sea_levels.loc[filter_2pt_med]
sea_levels_2pt_high = sea_levels.loc[filter_2pt_high]

# %%
years = ['RSL2020 (cm)', 'RSL2030 (cm)', 'RSL2040 (cm)', 'RSL2050 (cm)',
                    'RSL2060 (cm)', 'RSL2070 (cm)', 'RSL2080 (cm)', 'RSL2090 (cm)', 
                     'RSL2100 (cm)', 'RSL2110 (cm)', 'RSL2120 (cm)', 'RSL2130 (cm)',
                    'RSL2140 (cm)', 'RSL2150 (cm)']

# %%
pt3_low_avgs = sea_levels_pt3_low[years].mean()
pt3_med_avgs = sea_levels_pt3_med[years].mean()
pt3_high_avgs = sea_levels_pt3_high[years].mean()

pt5_low_avgs = sea_levels_pt5_low[years].mean()
pt5_med_avgs = sea_levels_pt5_med[years].mean()
pt5_high_avgs = sea_levels_pt5_high[years].mean()

_1pt_low_avgs = sea_levels_1pt_low[years].mean()
_1pt_med_avgs = sea_levels_1pt_med[years].mean()
_1pt_high_avgs = sea_levels_1pt_high[years].mean()

_1pt5_low_avgs = sea_levels_1pt5_low[years].mean()
_1pt5_med_avgs = sea_levels_1pt5_med[years].mean()
_1pt5_high_avgs = sea_levels_1pt5_high[years].mean()

_2pt_low_avgs = sea_levels_2pt_low[years].mean()
_2pt_med_avgs = sea_levels_2pt_med[years].mean()
_2pt_high_avgs = sea_levels_2pt_high[years].mean()

# %%
avg_sea_level_rise = pd.DataFrame({
    '0.3 - LOW': pt3_low_avgs,
    '0.3 - MED': pt3_med_avgs,
    '0.3 - HIGH': pt3_high_avgs,
    '0.5 - LOW': pt5_low_avgs,
    '0.5 - MED': pt5_med_avgs,
    '0.5 - HIGH': pt5_high_avgs,
    '1.0 - LOW': _1pt_low_avgs,
    '1.0 - MED': _1pt_med_avgs,
    '1.0 - HIGH': _1pt_high_avgs,
    '1.5 - LOW': _1pt5_low_avgs,
    '1.5 - MED': _1pt5_med_avgs,
    '1.5 - HIGH': _1pt5_high_avgs,
    '2.0 - LOW': _2pt_low_avgs,
    '2.0 - MED': _2pt_med_avgs,
    '2.0 - HIGH': _2pt_high_avgs
})

# %%
avg_sea_level_rise
# Out:
#               0.3 - LOW  0.3 - MED  0.3 - HIGH  0.5 - LOW   0.5 - MED  \
# RSL2020 (cm)   8.000000  10.428571   13.285714   8.142857   11.285714
# RSL2030 (cm)  12.714286  18.285714   23.857143  14.142857   19.714286
# RSL2040 (cm)  19.000000  26.000000   33.000000  21.000000   28.142857
# RSL2050 (cm)  25.142857  33.142857   41.857143  28.714286   36.857143
# RSL2060 (cm)  30.285714  39.285714   49.142857  36.000000   45.000000
# RSL2070 (cm)  34.142857  44.285714   55.142857  43.714286   53.285714
# RSL2080 (cm)  37.571429  48.428571   60.857143  50.285714   61.142857
# RSL2090 (cm)  41.000000  52.571429   65.857143  57.000000   68.571429
# RSL2100 (cm)  43.000000  57.857143   73.857143  62.857143   76.142857
# RSL2110 (cm)  46.714286  62.428571   81.142857  69.285714   85.000000
# RSL2120 (cm)  50.142857  67.428571   88.285714  75.857143   93.428571
# RSL2130 (cm)  53.285714  72.000000   94.857143  82.285714  102.428571
# RSL2140 (cm)  56.571429  76.714286  101.857143  88.428571  111.571429
# RSL2150 (cm)  59.571429  81.285714  108.428571  94.714286  120.857143
#
#               0.5 - HIGH   1.0 - LOW   1.0 - MED  1.0 - HIGH   1.5 - LOW  \
# RSL2020 (cm)   15.285714    8.285714   11.714286   15.000000    8.285714
# RSL2030 (cm)   25.714286   14.857143   20.571429   26.285714   15.000000
# RSL2040 (cm)   36.000000   22.857143   30.000000   38.000000   23.857143
# RSL2050 (cm)   45.428571   31.571429   40.142857   49.714286   34.857143
# RSL2060 (cm)   54.714286   41.857143   51.857143   62.857143   47.857143
# RSL2070 (cm)   64.142857   53.000000   65.000000   78.142857   61.857143
# RSL2080 (cm)   73.285714   66.142857   79.714286   95.285714   79.428571
# RSL2090 (cm)   82.428571   82.000000   99.000000  115.428571  100.142857
# RSL2100 (cm)   93.428571   96.000000  120.000000  140.000000  120.142857
# RSL2110 (cm)  104.428571  111.142857  142.714286  172.142857  139.571429
# RSL2120 (cm)  115.714286  125.285714  164.142857  212.857143  156.571429
# RSL2130 (cm)  127.571429  139.000000  183.428571  266.428571  172.571429
# RSL2140 (cm)  139.285714  151.571429  201.571429  333.857143  187.571429
# RSL2150 (cm)  151.571429  163.714286  218.714286  412.428571  201.571429
#
#                1.5 - MED  1.5 - HIGH   2.0 - LOW   2.0 - MED  2.0 - HIGH
# RSL2020 (cm)   11.857143   15.000000    8.571429   11.428571   15.000000
# RSL2030 (cm)   21.428571   28.000000   15.428571   21.714286   29.000000
# RSL2040 (cm)   32.285714   42.428571   24.428571   34.285714   46.428571
# RSL2050 (cm)   45.428571   60.000000   38.285714   50.714286   66.857143
# RSL2060 (cm)   62.857143   80.714286   56.000000   72.285714   92.428571
# RSL2070 (cm)   82.142857  103.571429   78.000000  101.000000  122.714286
# RSL2080 (cm)  104.285714  130.571429  102.000000  132.857143  157.428571
# RSL2090 (cm)  130.285714  156.857143  131.428571  167.714286  197.857143
# RSL2100 (cm)  158.571429  186.571429  163.714286  204.571429  239.571429
# RSL2110 (cm)  186.571429  220.714286  193.428571  243.714286  285.000000
# RSL2120 (cm)  207.285714  260.857143  218.142857  280.714286  335.428571
# RSL2130 (cm)  226.857143  299.000000  236.142857  312.857143  396.857143
# RSL2140 (cm)  245.285714  335.571429  251.142857  339.000000  468.571429
# RSL2150 (cm)  265.285714  383.428571  266.571429  363.000000  537.285714
