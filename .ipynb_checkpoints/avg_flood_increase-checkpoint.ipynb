# %%
import pandas as pd

# %%
# display all available columns (can do with rows)
pd.set_option("display.max_columns", 28)

# %%
sea_levels = pd.read_csv('sea_level_projections.csv')
sea_levels.head()
# Out:
#          PSMSL Site  PSMSL ID  NOAA ID                 NOAA Name  RSL GridNum  \
# 0  OCEAN_CITY_INLET      2292  8570280  OCEAN CITY, FISHING PIER        45825
# 1  OCEAN_CITY_INLET      2292  8570280  OCEAN CITY, FISHING PIER        45825
# 2  OCEAN_CITY_INLET      2292  8570280  OCEAN CITY, FISHING PIER        45825
# 3  OCEAN_CITY_INLET      2292  8570280  OCEAN CITY, FISHING PIER        45825
# 4  OCEAN_CITY_INLET      2292  8570280  OCEAN CITY, FISHING PIER        45825
#
#        Lat     Long Regional Classification  US Coastline Intersect (1 = yes)  \
# 0  38.3267 -75.0833               Northeast                                 1
# 1  38.3267 -75.0833               Northeast                                 1
# 2  38.3267 -75.0833               Northeast                                 1
# 3  38.3267 -75.0833               Northeast                                 1
# 4  38.3267 -75.0833               Northeast                                 1
#
# ...

# %%
sea_levels.drop(sea_levels.columns[28:116], axis=1, inplace=True)
sea_levels.head()
# Out:
#          PSMSL Site  PSMSL ID  NOAA ID                 NOAA Name  RSL GridNum  \
# 0  OCEAN_CITY_INLET      2292  8570280  OCEAN CITY, FISHING PIER        45825
# 1  OCEAN_CITY_INLET      2292  8570280  OCEAN CITY, FISHING PIER        45825
# 2  OCEAN_CITY_INLET      2292  8570280  OCEAN CITY, FISHING PIER        45825
# 3  OCEAN_CITY_INLET      2292  8570280  OCEAN CITY, FISHING PIER        45825
# 4  OCEAN_CITY_INLET      2292  8570280  OCEAN CITY, FISHING PIER        45825
#
#        Lat     Long Regional Classification  US Coastline Intersect (1 = yes)  \
# 0  38.3267 -75.0833               Northeast                                 1
# 1  38.3267 -75.0833               Northeast                                 1
# 2  38.3267 -75.0833               Northeast                                 1
# 3  38.3267 -75.0833               Northeast                                 1
# 4  38.3267 -75.0833               Northeast                                 1
#
# ...

# %%
sea_levels.shape
sea_levels.tail()
# Out:
#         PSMSL Site  PSMSL ID  NOAA ID   NOAA Name  RSL GridNum     Lat  \
# 100  WASHINGTON_DC       360  8594900  Washington        46183  38.873
# 101  WASHINGTON_DC       360  8594900  Washington        46183  38.873
# 102  WASHINGTON_DC       360  8594900  Washington        46183  38.873
# 103  WASHINGTON_DC       360  8594900  Washington        46183  38.873
# 104  WASHINGTON_DC       360  8594900  Washington        46183  38.873
#
#         Long Regional Classification  US Coastline Intersect (1 = yes)  \
# 100 -77.0217               Northeast                                 1
# 101 -77.0217               Northeast                                 1
# 102 -77.0217               Northeast                                 1
# 103 -77.0217               Northeast                                 1
# 104 -77.0217               Northeast                                 1
#
#        Scenario  RSL contribution from VLM (trend: cm/year)  \
# ...

# %%
sea_levels
# Out:
#            PSMSL Site  PSMSL ID  NOAA ID                 NOAA Name  \
# 0    OCEAN_CITY_INLET      2292  8570280  OCEAN CITY, FISHING PIER
# 1    OCEAN_CITY_INLET      2292  8570280  OCEAN CITY, FISHING PIER
# 2    OCEAN_CITY_INLET      2292  8570280  OCEAN CITY, FISHING PIER
# 3    OCEAN_CITY_INLET      2292  8570280  OCEAN CITY, FISHING PIER
# 4    OCEAN_CITY_INLET      2292  8570280  OCEAN CITY, FISHING PIER
# ..                ...       ...      ...                       ...
# 100     WASHINGTON_DC       360  8594900                Washington
# 101     WASHINGTON_DC       360  8594900                Washington
# 102     WASHINGTON_DC       360  8594900                Washington
# 103     WASHINGTON_DC       360  8594900                Washington
# 104     WASHINGTON_DC       360  8594900                Washington
#
#      RSL GridNum      Lat     Long Regional Classification  \
# 0          45825  38.3267 -75.0833               Northeast
# ...

# %%
filter_pt_3_low = (sea_levels['Scenario'] == '0.3 - LOW')

# %%
sea_levels_pt_3_low = sea_levels.loc[filter_pt_3_low]
sea_levels_pt_3_low
# Out:
#           PSMSL Site  PSMSL ID  NOAA ID  \
# 1   OCEAN_CITY_INLET      2292  8570280
# 16      CAMBRIDGE_II      1295  8571892
# 31  TOLCHESTER_BEACH      2323  8573364
# 46         BALTIMORE       148  8574680
# 61         ANNAPOLIS       311  8575512
# 76  SOLOMON'S_ISLAND       412  8577330
# 91     WASHINGTON_DC       360  8594900
#
#                                   NOAA Name  RSL GridNum        Lat  \
# 1                  OCEAN CITY, FISHING PIER        45825  38.326700
# 16                                Cambridge        46184  38.572500
# 31                         Tolchester Beach        46184  39.213400
# 46  Baltimore, Fort McHenry, Patapsco River        46183  39.266944
# 61                                Annapolis        46184  38.983280
# 76                          Solomons Island        45824  38.317222
# 91                               Washington        46183  38.873000
#
#          Long Regional Classification  US Coastline Intersect (1 = yes)  \
# ...

# %%
pt_3_low_avgs = sea_levels_pt_3_low[['RSL2020 (cm)', 'RSL2030 (cm)', 'RSL2040 (cm)', 'RSL2050 (cm)',
                    'RSL2060 (cm)', 'RSL2070 (cm)', 'RSL2080 (cm)', 'RSL2090 (cm)', 
                     'RSL2100 (cm)', 'RSL2110 (cm)', 'RSL2120 (cm)', 'RSL2130 (cm)',
                    'RSL2140 (cm)', 'RSL2150 (cm)']].mean()
# Out:
# RSL2020 (cm)     8.000000
# RSL2030 (cm)    12.714286
# RSL2040 (cm)    19.000000
# RSL2050 (cm)    25.142857
# RSL2060 (cm)    30.285714
# RSL2070 (cm)    34.142857
# RSL2080 (cm)    37.571429
# RSL2090 (cm)    41.000000
# RSL2100 (cm)    43.000000
# RSL2110 (cm)    46.714286
# RSL2120 (cm)    50.142857
# RSL2130 (cm)    53.285714
# RSL2140 (cm)    56.571429
# RSL2150 (cm)    59.571429
# dtype: float64

# %%
filter_pt_3_med = (sea_levels['Scenario'] == '0.3 - MED')

# %%
sea_levels_pt_3_med = sea_levels.loc[filter_pt_3_med]
sea_levels_pt_3_med
# Out:
#           PSMSL Site  PSMSL ID  NOAA ID  \
# 0   OCEAN_CITY_INLET      2292  8570280
# 15      CAMBRIDGE_II      1295  8571892
# 30  TOLCHESTER_BEACH      2323  8573364
# 45         BALTIMORE       148  8574680
# 60         ANNAPOLIS       311  8575512
# 75  SOLOMON'S_ISLAND       412  8577330
# 90     WASHINGTON_DC       360  8594900
#
#                                   NOAA Name  RSL GridNum        Lat  \
# 0                  OCEAN CITY, FISHING PIER        45825  38.326700
# 15                                Cambridge        46184  38.572500
# 30                         Tolchester Beach        46184  39.213400
# 45  Baltimore, Fort McHenry, Patapsco River        46183  39.266944
# 60                                Annapolis        46184  38.983280
# 75                          Solomons Island        45824  38.317222
# 90                               Washington        46183  38.873000
#
#          Long Regional Classification  US Coastline Intersect (1 = yes)  \
# ...
